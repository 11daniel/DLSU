# %% [markdown]
# # Introduction to Machine Learning Notebook
#
# Welcome to our **Machine Learning Notebook**! In this concise guide, you'll explore the exciting realm of machine learning using popular Python libraries such as:
# - **pandas**
# - **matplotlib**
# - **numpy**, and
# - **scikit-learn**. <br>
#
# Whether you're new to the field or an experienced data scientist, this notebook offers hands-on experience with basic machine learning algorithms and practical applications.
# - **Pandas Documentation**: https://pandas.pydata.org/docs/
# - **Matplotlib Documentation**: https://matplotlib.org/stable/index.html
# - **Numpy Documentation**: https://numpy.org/doc/
# - **Scikit-Learn**: https://scikit-learn.org/stable/

# %% [markdown]
# Before anything else, we should mount our Google Colab to our Google Drive to access the datasets.

# %%
# This is only if you are using Google Colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# For the succeeding process, we will follow the machine learning pipeline.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 0. ML Problem
# - Identify the Machine Learning problem
# - Create research questions

# %% [markdown]
# In this case, we will identify the species of flowers given the measurement of **Sepal Length** and **Petal Length**.
# - One research question can be:
# 1. How many species are present in the given dataset?
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 1. Data
# - Data Collection
# - Data Preprocessing
#   - Cleaning
#   - Transformation
#   - Organization
# - Creating Training and Testing Set<br/><br/>
# ![image.png](data:image/png;base64,...)

# %%
# Import pandas library for reading the dataset

# Import numpy library for matrix manipulation

# Import matplotlib for data visualization

# %%
# Read the dataset

# Show the data

# %%
# Check the data information

# %%
# Visualize the data

# %%
# Shuffle the data to reduce bias

# %%
# Fix the index

# %% [markdown]
# ## Creating Training and Testing Dataset
# - 70% of the data is for training
# - 30% of the data is for testing

# %%
# Compute for the 70% of the dataset

# %%
# Separate the dataset into training and testing sets

# %%
# Check training set

# %%
# Check testing set

# %% [markdown]
# # 2. Training
# - Choose a Machine Learning model
# - Choose a loss function for training that is suitable for the ML model
# - Input the training set to the model and compute for the loss function
# <br/><br/>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In our case we will choose **K-Means Clustering** as our Machine Learning model and **Sum of Squared Distances** as our loss function. <br/><br/>
# ![image.png](data:image/png;base64,...)

# %%
# Import scikit-learn's KMeans clustering algorithm

# %%
# Convert the training set to a matrix (numpy format)
# Remove the Id

# %%
# Create the K-Means Clustering Model
# Try k = 5

# %%
# Show the sum of squared distances

# %%
# Check in the training data

# %% [markdown]
# # 3. Training + Hyperparameter Tuning
# - continuous training and configure hyperparameters of the model
# - determine the best hyperparameters of the model <br/><br/>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In our case, we will use the **elbow method** for K-Means Clustering to tune the hyperparameter *k*. <br/><br/>
# ![image.png](data:image/png;base64,...)

# %%
# Create a loop to configure the hyperparameter

# %%
# Plot the loss

# %%
# Select the best model based on "elbow method"

# %%
# Add the labels in the testing dataset

# %%
# Visualize the cluster

# %% [markdown]
# If **ground truth is present**, then we can check the results of clustering.

# %%
# Read the ground truth data

# %%
# Check the number of species in the ground truth

# %%
# Visualize the ground truth

# %%
# Convert the labels similar to the training

# %%
# Merge the ground truth to the test dataset

# %%
# Import the scikit learn library for calculating accuracy

# %%
# Calculate the accuracy score

# %% [markdown]
# ### Simple Supervised Linear Regression

# %%
# Import new dataset

# %%
# Check the dataset information

# %%
# Drop NA values

# %%
# Import scikit learn library for splitting the dataset into random train and test subsets

# %%
# Import the necessary libraries for linear regression

# %%
# Reshape the date into prescribed format of scikit learn (# of samples, # of features)
# -1: automatically infer the size of one of the dimensions based on the size of the data

# %%
# Create a Linear Regression model


# Fit the model to the training data

# %%
# Make predictions on the testing data


# Calculate the R-squared score to evaluate the model

# %%
# Create a New Dataframe comparing the actual and predicted exam scores in the test data

# %%
# Create a scatter plot visualize the relationship between Study Hours and Exam Score


# Add the regression line plot to show the Score Prediction based on Actual Scores

# %%
# Check the line equation
